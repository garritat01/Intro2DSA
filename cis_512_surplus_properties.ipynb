# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style="ticks", color_codes=True)

# %matplotlib inline
path = 'C:/Users/garritat/Desktop/cis_512/'
file_name = 'https://data.ny.gov/resource/as7q-hqm6.json'
##file_name  ='Monthly_Recycling_and_Waste_Collection_Statistics.csv'
full = path+file_name
df = pd.read_json(file_name)

# %%
df.head()
# Out:
#    area_acres                  closing   county  \
# 0       3.240  2005-03-21T00:00:00.000     Erie
# 1       0.000  2005-03-21T00:00:00.000  MADISON
# 2       0.087  2005-06-10T00:00:00.000     ERIE
# 3       0.097  2005-06-15T00:00:00.000     ERIE
# 4       0.775  2005-08-11T00:00:00.000  MADISON
#
#                     method_of_disposal  region  saleprice
# 0                         PRIVATE SALE       5   176000.0
# 1                    GRANT OF EASEMENT       2        0.0
# 2                         Private Sale       5    67000.0
# 3  RELEASE OF MAINTENANCE JURISDICTION       5        1.0
# 4                         PRIVATE SALE       2     2000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 6 columns):
# area_acres            271 non-null float64
# closing               283 non-null object
# county                283 non-null object
# method_of_disposal    279 non-null object
# region                283 non-null int64
# saleprice             274 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 13.3+ KB

# %%
to_drop = ['method_of_disposal']
df.drop(to_drop, inplace=True, axis=1)

# %%
df.columns
# Out:
# Index(['area_acres', 'closing', 'county', 'region', 'saleprice'], dtype='object')

# %%
df.isnull().values.any()
# Out:
# True

# %%
nan_rows = df[df['saleprice'].isnull()]
nan_rows
# Out:
#      area_acres                  closing    county  region  saleprice
# 40          NaN  2007-08-16T00:00:00.000    WARREN     1.0        NaN
# 114         NaN  2010-05-25T00:00:00.000   SUFFOLK    10.0        NaN
# 145       0.658  2011-03-30T00:00:00.000    MONROE     4.0        NaN
# 146       0.232  2011-04-27T00:00:00.000    Ulster     8.0        NaN
# 156       0.841  2011-09-23T00:00:00.000    MONROE     4.0        NaN
# 162         NaN  2012-01-05T00:00:00.000  HAMILTON     2.0        NaN
# 165       0.787  2012-02-13T00:00:00.000    Monroe     4.0        NaN
# 166       1.150  2012-02-13T00:00:00.000    MONROE     4.0        NaN
# 175       0.090  2012-05-03T00:00:00.000   SUFFOLK    10.0        NaN
# 278       0.000                      NaN       NaN     NaN        NaN
# 40        0.000                      NaN       NaN     NaN        NaN
# 114       0.000                      NaN       NaN     NaN        NaN
# ...

# %%
df2 = df.index[df['saleprice'] > 0]

# %%
df.set_value('40', 'area_acres', 0)
df.set_value('114', 'area_acres', 0)
df.set_value('162', 'area_acres', 0)
# Out:
# C:\anaconda\envs\geopandas_environment\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """Entry point for launching an IPython kernel.
# C:\anaconda\envs\geopandas_environment\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\anaconda\envs\geopandas_environment\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#      area_acres                  closing        county  region  saleprice
# 0         3.240  2005-03-21T00:00:00.000          Erie     5.0   176000.0
# 1         0.000  2005-03-21T00:00:00.000       MADISON     2.0        0.0
# ...

# %%
nan_rows = df[df['area_acres'].isnull()]

# %%
nan_rows
# Out:
#      area_acres                  closing       county  region  saleprice
# 40          NaN  2007-08-16T00:00:00.000       WARREN     1.0        NaN
# 75          NaN  2008-12-15T00:00:00.000         ERIE     5.0    25000.0
# 87          NaN  2009-06-05T00:00:00.000       OTSEGO     9.0        1.0
# 100         NaN  2009-10-30T00:00:00.000         ERIE     5.0    45700.0
# 114         NaN  2010-05-25T00:00:00.000      SUFFOLK    10.0        NaN
# 125         NaN  2010-08-17T00:00:00.000     DUTCHESS     8.0   283000.0
# 150         NaN  2011-08-01T00:00:00.000       ORANGE     8.0        0.0
# 160         NaN  2011-11-28T00:00:00.000       MONROE     4.0        1.0
# 162         NaN  2012-01-05T00:00:00.000     HAMILTON     2.0        NaN
# 218         NaN  2013-04-18T00:00:00.000       ONEIDA     2.0        1.0
# 226         NaN  2013-05-31T00:00:00.000  WESTCHESTER     8.0        1.0
